# %% [markdown]
# HW 4 540
#
# 1. Generate random 150 MVN data, p=21.
#
# The covariance matrix should be positive semi- definite symmetric matrix.
#
# (1) Calculate sample covariance matrix.
#
# (2) Find out the first three principal components.
#
# (3) Calcuate the proportions of the variability of data that can be explained by the first K principal components and find the value of K that it reaches to 99% of the variability.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import *
from numpy import *
from sklearn import preprocessing,datasets, linear_model
from sklearn.decomposition import PCA
# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# (1) Calculate sample covariance matrix.

# %%
# p=21
# The Multivariate  normal distribution with p =21 mean vector is mu.
# The covariance matrix is cov.
mu = np.random.uniform(-10,10,size=21)
C = np.random.random((21,21))
cov = C @ C.T # positive semi-definite

# %%
plt.rcParams['figure.figsize']=(8,8)
plt.matshow(cov)
plt.show()

# %% [markdown]
# (2) Find out the first three principal components.

# %%
Ns = 150 #Generate 150 samples from x1-x21
data = np.random.multivariate_normal(mu, cov, size=Ns)

# %%
#normalize data
scaler = preprocessing.StandardScaler().fit(data)
data_scaled = scaler.transform(data)
data_n = np.cov(data_scaled)
pd.DataFrame(data_n)
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.170902 -0.107244  0.022699  0.029599  0.018263  0.033154 -0.084936
# 1   -0.107244  0.362012 -0.012157 -0.098574 -0.021286 -0.186241 -0.032833
# 2    0.022699 -0.012157  0.130487 -0.101403 -0.011502 -0.040140 -0.001268
# 3    0.029599 -0.098574 -0.101403  0.350420  0.063872  0.143011 -0.024177
# 4    0.018263 -0.021286 -0.011502  0.063872  0.157197  0.004150 -0.104089
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.066823 -0.038107 -0.042802  0.065796  0.055936 -0.068146 -0.088328
# 146  0.094236 -0.166912 -0.018269 -0.025201 -0.044297  0.061068  0.102905
# 147 -0.040795 -0.063473  0.022361 -0.035133 -0.058289  0.203422  0.076716
# 148  0.001936 -0.068417  0.041026  0.008124 -0.021166  0.005450  0.004769
# 149 -0.024210  0.093790  0.054147 -0.099752 -0.037412 -0.126851  0.030601
#
#           7         8         9    ...       140       141       142  \
# 0    0.002212 -0.067466  0.036053  ... -0.058220 -0.082690  0.092187
# 1   -0.055118  0.065067 -0.031193  ...  0.113951  0.051926 -0.067187
# 2    0.036334 -0.052053 -0.001848  ... -0.012061  0.000094  0.047133
# 3   -0.051232  0.067228  0.010844  ... -0.038911 -0.021546 -0.018806
# 4   -0.012891  0.079723 -0.061231  ... -0.033325 -0.117501 -0.051727
# ..        ...       ...       ...  ...       ...       ...       ...
# 145 -0.017967  0.022615 -0.005740  ...  0.017447 -0.053333 -0.022125
# 146 -0.006280 -0.168392  0.013518  ... -0.020086 -0.048266  0.143746
# 147  0.083802 -0.025751 -0.027201  ...  0.005843  0.090607 -0.026857
# 148  0.048494  0.061200 -0.030699  ... -0.013930  0.013607 -0.029110
# 149 -0.032609 -0.061957 -0.014752  ...  0.024397  0.015404  0.059916
#
#           143       144       145       146       147       148       149
# 0   -0.084401  0.008679  0.066823  0.094236 -0.040795  0.001936 -0.024210
# 1    0.029985  0.014805 -0.038107 -0.166912 -0.063473 -0.068417  0.093790
# 2   -0.133809 -0.051633 -0.042802 -0.018269  0.022361  0.041026  0.054147
# 3    0.140070  0.015892  0.065796 -0.025201 -0.035133  0.008124 -0.099752
# 4    0.046625 -0.061515  0.055936 -0.044297 -0.058289 -0.021166 -0.037412
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.001208 -0.016612  0.221642 -0.021797 -0.194731  0.001602 -0.032244
# 146  0.013503 -0.018096 -0.021797  0.308711  0.041685 -0.043028  0.000218
# 147 -0.053943  0.063968 -0.194731  0.041685  0.352650  0.057150 -0.029240
# 148 -0.053026  0.016531  0.001602 -0.043028  0.057150  0.210044 -0.032199
# 149 -0.036095 -0.082671 -0.032244  0.000218 -0.029240 -0.032199  0.131228
#
# [150 rows x 150 columns]

# %%
#PCA by mle function
pca=PCA(n_components='mle')
pca.fit(data_n)
data_pca = pca.transform(data_n)
# pd.DataFrame(data_pca)

# %%
plt.rcParams['figure.figsize']=(5,5)
plt.matshow(data_pca)
plt.show()

# %% [markdown]
# we can see the data after pca converges in the first 10 principle components

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
# let n = 3 ,find the first 3 principle components

# %%
#PCA where n=3
pca3=PCA(n_components=3)
pca.fit(data_n)
data_pca3 = pca.transform(data_n)
# pd.DataFrame(data_pca)

# %%
plt.rcParams['figure.figsize']=(5,5)
plt.matshow(data_pca3)
plt.show()

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
plt.style.use("ggplot")
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.figsize']=(8,8)
plt.scatter(data_n[:,0],data_n[:,1],label='x1,x2')
plt.title("")
plt.axis('equal')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use("ggplot")
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.figsize']=(8,8)
plt.scatter(data_n[:,1],data_n[:,2],label='x2,x3')
plt.title("")
plt.axis('equal')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.style.use("ggplot")
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.figsize']=(8,8)
plt.scatter(data_n[:,0],data_n[:,2],label='x1,x3')
plt.title("")
plt.axis('equal')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# (3) Calcuate the proportions of the variability of data that can be explained by the first K principal components and find the value of K that it reaches to 99% of the variability.

# %%
pca = PCA().fit(data_pca)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %%
# pd.DataFrame(pca.explained_variance_ratio_)

# %%
k = 0
for i in range(12):
    k = k + pca.explained_variance_ratio_[i]
    print(k)
# Out:
# 0.29009464569704174
# 0.49834348406846246
# 0.6548470043238959
# 0.7633277208091434
# 0.8317088526230886
# 0.8898038999404491
# 0.9280243002583163
# 0.9538563660480119
# 0.9691307417987703
# 0.9787808604635798
# 0.984942391269664
# 0.9902760071395881

# %% [markdown]
# So we find k = 11,first K principal components and find the value of K that it reaches to 99% of the variability.

# %% [markdown]
# 2. Generate $Y$ values using the following regression functions:
#
# $Y=5+2 X_{1}+5 X_{3}+$ $3 X_{19}+\epsilon$
#
# for the generated X matrix in #1
#
#  (1) Estimate the regression line using the least square method and find out the predicted values, residuals for each observation and the mean square errors for both Trainning and testing data.
#
# (2) Estimate the regression line using the least square method based on the first 5 principal components and find out the predicted values, residuals for each observation and the mean square errors for both Trainning and testing data.
#
# (3) Compare the results in (1) and (2).
#
# Here we define:
# $\epsilon$~N(0,4)
#
# Trainning set :150
#
# Testing set: 50

# %%
#  (1) Estimate the regression line using the least square method and find out the predicted values, residuals for each observation and the mean square errors for both Trainning and testing data.
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error,r2_score

# %%
#In Q1 ,we have:
# Ns = 200 #Generate 200 samples from x1-x20
# data = np.random.multivariate_normal(mu, cov, size=Ns)
x1 = data[:, 0]
x3 = data[:, 2]
x5 = data[:, 4]
x19 = data[:,18]

# now define Gaussian noise:
mu_e, sigma_e = 0, 4
xe = norm.rvs(mu_e,sigma_e,size=Ns)

Y = 5 + 2*x1 + 5*x3 + 3*x19 + xe

# %% [markdown]
# For trainning data

# %%
x_matrix = pd.DataFrame([x1,x3,x19]).T 
y_matrix = pd.DataFrame([Y]).T

# %%
x_train = x_matrix[:-50]
x_test = x_matrix[100:]
y_train = y_matrix[:-50]
y_test = y_matrix[100:]

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(x_test)

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [[2.09939641 4.87278329 3.01065942]]

# %%
#MSE
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 11.44

# %%
print('Variance score: %.2f(best fit = 1)' % r2_score(y_test, y_pred))
# Out:
# Variance score: 0.98(best fit = 1)

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# For testing data

# %%
regr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred_train = regr.predict(x_train)

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [[2.10503054 4.36903623 3.21916969]]

# %%
#MSE
print("Mean squared error: %.2f"% mean_squared_error(y_train, y_pred_train))
# Out:
# Mean squared error: 22.10

# %%
print('Variance score: %.2f(best fit = 1)' % r2_score(y_train, y_pred_train))
# Out:
# Variance score: 0.96(best fit = 1)

# %%
fig, ax = plt.subplots()
ax.scatter(y_train, y_pred_train)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
# (2) Estimate the regression line using the least square method based on the first 5 principal components and find out the predicted values, residuals for each observation and the mean square errors for both Trainning and testing data.

# %%
#PCA by mle function
pca=PCA(n_components='mle')
pca.fit(data_n)
data_pca = pca.transform(data_n)
# pd.DataFrame(data_pca)

# %%
pca5 = data[:,:5]
# coefficients of pcs
# pc5 = pd.DataFrame(pca5)
data5 = data[:,:5]
# pd.DataFrame(data5)
y5 = pca5 * data5

# %%
x_train5 = data5[:-50]
x_test5 = data5[100:]
y_train5 = y5[:-50]
y_test5 = y5[100:]

# %% [markdown]
# For trainning data

# %%
regr.fit(x_train5,y_train5)
# Out:
# LinearRegression()

# %%
y_pred5 = regr.predict(x_test5)

# %%
#MSE
print("Mean squared error: %.2f"% mean_squared_error(y_test5, y_pred5))
# Out:
# Mean squared error: 152.54

# %%
print('Variance score: %.2f(best fit = 1)' % r2_score(y_test5, y_pred5))
# Out:
# Variance score: 0.69(best fit = 1)

# %%
fig, ax = plt.subplots()
ax.scatter(y_test5, y_pred5)
ax.plot([y_test5.min(), y_test5.max()], [y_test5.min(), y_test5.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# For testing data

# %%
regr.fit(x_test5,y_test5)
# Out:
# LinearRegression()

# %%
y_pred5_train = regr.predict(x_train5)

# %%
print("Mean squared error: %.2f"% mean_squared_error(y_train5, y_pred5_train))
# Out:
# Mean squared error: 98.72

# %%
print('Variance score: %.2f(best fit = 1)' % r2_score(y_train5, y_pred5_train))
# Out:
# Variance score: 0.75(best fit = 1)

# %%
fig, ax = plt.subplots()
ax.scatter(y_train5, y_pred5_train)
ax.plot([y_test5.min(), y_test5.max()], [y_test5.min(), y_test5.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
# (3) Compare the results in (1) and (2).

# %% [markdown]
# Based on the data and test 1 and 2 the ,the reusults 1 performed better with the lower MSE and better regression in graph.
